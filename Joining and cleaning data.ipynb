# %% [markdown]
# # Breaking down and studying my QS data

# %% [markdown]
# Better living through data. One of my favorite hobbies is to use data to get a better understanding of my habits. Using both my IFTTT data and my Finance App

# %%
#libraries that I'm using
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Getting the finance data:

# %%
#path to my files (I'll come back here a lot so
#I'll keep this as a global variable)
path = "C:\Users\Bill\Google Drive\Finance\{}"

# %%
#I keep my archived finance data in CSVs
finance_files = ["transactions2014.csv",
			"transactions2015_1.csv",
			"transactions2015_2.csv"]

# %%
frames = [pd.read_csv(path.format(x)) for x in finance_files]
df = pd.concat(frames).reset_index(drop=True)
df = df.drop_duplicates(subset='Unique mail id').reset_index(drop=True)
df.head()
# Out:
#   Date of pull    Unique mail id          Reciept text   Date  Amount  \
# 0      7/10/14  1471cefe61af52ac  PACIFIC SUPPLY CO...  41829   18.51
# 1      7/10/14  1471dd507b0c3b83            RHINO ROOM  41829   10.00
# 2      7/10/14  14718cb3d1bc998c      CENTURY BALLROOM  41828   55.00
# 3      7/10/14  1471966915ab72a3            RHINO ROOM  41829   20.00
# 4      7/10/14  147125097a342e9f      KOHL&#39;S #1053  41827   29.99
#
#      Time EST  Month  Day  Hour        Category
# 0   0.7104861      7    9    17     Arts&Crafts
# 1   0.8842014      7    9    21  Out for drinks
# 2   0.9058912      7    8    21  Out for drinks
# 3  0.02373843      7    9     0  Out for drinks
# 4   0.6478125      7    7    15     Arts&Crafts

# %% [markdown]
# After collecting data for most of 2014, I made some major changes in the application that affected the dates.  Really I wanted to just clean it out and forget it but I thought that this would be a good data cleaning example:

# %%
#fix that pesky date issue that I didn't fix before:
df['isDate'] = df.Date.apply(lambda x: '/' in str(x))
df.loc[df['isDate']==False,'Date'] = df.loc[df['isDate']==False,'Date of pull']
df.head()
# Out:
#   Date of pull    Unique mail id          Reciept text     Date  Amount  \
# 0      7/10/14  1471cefe61af52ac  PACIFIC SUPPLY CO...  7/10/14   18.51
# 1      7/10/14  1471dd507b0c3b83            RHINO ROOM  7/10/14   10.00
# 2      7/10/14  14718cb3d1bc998c      CENTURY BALLROOM  7/10/14   55.00
# 3      7/10/14  1471966915ab72a3            RHINO ROOM  7/10/14   20.00
# 4      7/10/14  147125097a342e9f      KOHL&#39;S #1053  7/10/14   29.99
#
#      Time EST  Month  Day  Hour        Category isDate
# 0   0.7104861      7    9    17     Arts&Crafts   True
# 1   0.8842014      7    9    21  Out for drinks   True
# 2   0.9058912      7    8    21  Out for drinks   True
# 3  0.02373843      7    9     0  Out for drinks   True
# 4   0.6478125      7    7    15     Arts&Crafts   True

# %% [markdown]
# OK cool but some of the data is '%m/%d/%Y' and some of it is '%m/%d/%y'.   OR 1/1/2014 and 1/1/14.  That's a problem. The fixYear function might not be the best but is fine for this as there are only two different scenarios.

# %%
def fixYear(x):
	try:
		y = datetime.strptime(x, '%m/%d/%Y')
	except:
		y = datetime.strptime(x, '%m/%d/%y')
	return y
df['dataObje'] = df['Date'].apply(lambda X: fixYear(X))

# %%
df['dataObje'][1]
# Out:
# Timestamp('2014-07-10 00:00:00')

# %% [markdown]
# Awesome, I have a timestamp object for each transaction. This will come in handy later.

# %% [markdown]
# IFTTT is collected and filtered in annother process (google app script). look in the IFTTT_event_translations.js. Here I'm loading that file from CSV.

# %% [markdown]
# ## Adding the IFTTT data:

# %%
df2 = pd.read_csv(path.format("Home Data - Event Log.csv"),encoding="utf-8")

# %%
df2.head()
# Out:
#    Year  Month  Day      Hour  Duration                 Activity
# 0  2015     11   17  12:00 AM       265  Going from work to home
# 1  2015     11   17  12:00 AM       120      Hanging out at home
# 2  2015     11   17        18         2    Went out, not to work
# 3  2015     11   17  12:00 AM         0      Hanging out at home
# 4  2015     11   17  12:00 AM       779  Going from home to work

# %% [markdown]
# Now I need a timestamp that matches the one from the finance data:

# %%
df2['Date'] = df2['Month'].map(str) + "/" + df2['Day'].map(str) + "/" + df2['Year'].map(str)

# %% [markdown]
# ## Transforming and merging the two sets together:

# %% [markdown]
# ### First the Activity data:

# %%
activities = pd.DataFrame(df2.pivot_table(index="Date",columns="Activity",values="Duration",aggfunc="sum"))
#I'm only showing a subset of the columns to the public
cols =  ["Going from home to work",
		"Going from work to home",
		"Hanging out at home",
		"Left work for a bit, and came back",
		"Went out, not to work",
		"Working"]
activities = activities[cols]
activities.head()
# Out:
# Activity  Going from home to work  Going from work to home  \
# Date
# 1/1/2016                      NaN                      NaN
# 1/2/2016                      NaN                      NaN
# 1/3/2016                      NaN                      NaN
# 1/4/2016                      NaN                       66
# 1/5/2016                       41                       31
#
# Activity  Hanging out at home  Left work for a bit, and came back  \
# Date
# 1/1/2016                 1704                                 NaN
# 1/2/2016                 1040                                 NaN
# 1/3/2016                  364                                 NaN
# 1/4/2016                  897                                  13
# 1/5/2016                  969                                  25
#
# Activity  Went out, not to work  Working
# Date
# 1/1/2016                    192      NaN
# 1/2/2016                    143      NaN
# 1/3/2016                     34      NaN
# 1/4/2016                    NaN      579
# 1/5/2016                    NaN      320

# %% [markdown]
# ### Then the expense data:

# %%
expenses = pd.DataFrame(df.pivot_table(index="Date",columns="Category",values="Amount",aggfunc="sum"))
#I'm only showing a subset of the columns to the public
cols =  ['Arts&Crafts', 
		'Coffee', 
		'Eating at Home', 
		'Eating out', 
		'Grocery', 
		'Lunch', 
		'Out for drinks',
		'Out of town',  
		'Transportation']
expenses = expenses[cols]
expenses.head()
# Out:
# Category   Arts&Crafts  Coffee  Eating at Home  Eating out  Grocery  Lunch  \
# Date
# 1/1/2015           NaN     NaN           14.80         NaN      NaN    NaN
# 1/1/2016           NaN     NaN             NaN         NaN    44.38    NaN
# 1/10/2015          NaN     NaN             NaN         6.5      NaN   8.19
# 1/11/2015          NaN     NaN           23.48        12.0      NaN    NaN
# 1/12/2015          NaN     NaN           29.91         NaN      NaN    NaN
#
# Category   Out for drinks  Out of town  Transportation
# Date
# 1/1/2015              NaN          NaN            6.95
# 1/1/2016              NaN          NaN             NaN
# 1/10/2015              15          NaN             NaN
# 1/11/2015             NaN          NaN             NaN
# 1/12/2015             NaN          NaN             NaN

# %% [markdown]
# ### Then you merge:

# %% [markdown]
# Note: My IFTTT data only goes back to November 2015. So lots of blanks.

# %%
data = pd.merge(activities,expenses,left_index=True,right_index=True,how="outer")
data.head()
# Out:
#            Going from home to work  Going from work to home  \
# Date
# 1/1/2015                       NaN                      NaN
# 1/1/2016                       NaN                      NaN
# 1/10/2015                      NaN                      NaN
# 1/11/2015                      NaN                      NaN
# 1/12/2015                      NaN                      NaN
#
#            Hanging out at home  Left work for a bit, and came back  \
# Date
# 1/1/2015                   NaN                                 NaN
# 1/1/2016                  1704                                 NaN
# 1/10/2015                  NaN                                 NaN
# 1/11/2015                  NaN                                 NaN
# 1/12/2015                  NaN                                 NaN
#
#            Went out, not to work  Working  Arts&Crafts  Coffee  \
# Date
# 1/1/2015                     NaN      NaN          NaN     NaN
# 1/1/2016                     192      NaN          NaN     NaN
# 1/10/2015                    NaN      NaN          NaN     NaN
# 1/11/2015                    NaN      NaN          NaN     NaN
# 1/12/2015                    NaN      NaN          NaN     NaN
#
#            Eating at Home  Eating out  Grocery  Lunch  Out for drinks  \
# Date
# 1/1/2015            14.80         NaN      NaN    NaN             NaN
# 1/1/2016              NaN         NaN    44.38    NaN             NaN
# 1/10/2015             NaN         6.5      NaN   8.19              15
# 1/11/2015           23.48        12.0      NaN    NaN             NaN
# 1/12/2015           29.91         NaN      NaN    NaN             NaN
#
#            Out of town  Transportation
# Date
# 1/1/2015           NaN            6.95
# 1/1/2016           NaN             NaN
# 1/10/2015          NaN             NaN
# 1/11/2015          NaN             NaN
# 1/12/2015          NaN             NaN

# %% [markdown]
# Check to see if that matched right

# %%
print (activities['Hanging out at home']['1/1/2016']/60, activities['Went out, not to work']['1/1/2016']/60)
# Out:
# (28.399999999999999, 3.2000000000000002)

# %% [markdown]
# Yup. New Year’s day I was at home pretty much the whole day. It's over 24 hours because it counts the number of minutes until the next log event (aka leaving home). In that case there could be more than 24 hours of an activity. The best way to think about it is that 1/1/2016 is the day that a 28 hour activity began. Also went out for about 3.5 hours that day and bought some groceries, so cool.

# %% [markdown]
# ### Output to Excel for manual analysis:

# %%
writer = pd.ExcelWriter(path.format('output.xlsx'))
data.to_excel(writer,'all data')
data.corr().to_excel(writer,'correlation')
activities.to_excel(writer,'activities')
expenses.to_excel(writer,'expenses')
df.to_excel(writer,'transactions')
df2.to_excel(writer,'IFTTT events')
writer.save()

# %%
data.corr()
# Out:
#                                     Going from home to work  \
# Going from home to work                            1.000000
# Going from work to home                            0.033354
# Hanging out at home                               -0.420076
# Left work for a bit, and came back                -0.453779
# Went out, not to work                             -0.147981
# Working                                            0.049449
# Arts&Crafts                                             NaN
# Coffee                                            -0.381452
# Eating at Home                                          NaN
# Eating out                                        -0.429881
# Grocery                                           -0.121395
# Lunch                                              0.179227
# Out for drinks                                    -0.411878
# Out of town                                        0.253556
# Transportation                                    -0.476853
#
#                                     Going from work to home  \
# Going from home to work                            0.033354
# Going from work to home                            1.000000
# Hanging out at home                               -0.176807
# Left work for a bit, and came back                -0.142643
# Went out, not to work                             -0.185477
# Working                                            0.134676
# Arts&Crafts                                             NaN
# Coffee                                            -0.403281
# Eating at Home                                          NaN
# Eating out                                         0.775654
# Grocery                                            0.992059
# Lunch                                             -0.209777
# Out for drinks                                     0.393253
# Out of town                                       -0.188708
# Transportation                                    -0.347392
#
#                                     Hanging out at home  \
# Going from home to work                       -0.420076
# Going from work to home                       -0.176807
# Hanging out at home                            1.000000
# Left work for a bit, and came back            -0.538310
# Went out, not to work                         -0.281327
# Working                                        0.373251
# Arts&Crafts                                         NaN
# Coffee                                         0.046769
# Eating at Home                                 0.730664
# Eating out                                     0.478270
# Grocery                                       -0.059380
# Lunch                                          0.624699
# Out for drinks                                 0.284195
# Out of town                                   -0.272248
# Transportation                                -0.234316
#
#                                     Left work for a bit, and came back  \
# Going from home to work                                      -0.453779
# Going from work to home                                      -0.142643
# Hanging out at home                                          -0.538310
# Left work for a bit, and came back                            1.000000
# Went out, not to work                                         0.022847
# Working                                                      -0.154687
# Arts&Crafts                                                        NaN
# Coffee                                                       -0.475884
# Eating at Home                                                     NaN
# Eating out                                                   -0.306007
# Grocery                                                      -0.327740
# Lunch                                                        -0.373126
# Out for drinks                                               -0.087757
# Out of town                                                   0.448955
# Transportation                                               -0.143721
#
#                                     Went out, not to work   Working  \
# Going from home to work                         -0.147981  0.049449
# Going from work to home                         -0.185477  0.134676
# Hanging out at home                             -0.281327  0.373251
# Left work for a bit, and came back               0.022847 -0.154687
# Went out, not to work                            1.000000  0.148356
# Working                                          0.148356  1.000000
# Arts&Crafts                                           NaN       NaN
# Coffee                                           0.247815 -0.311486
# Eating at Home                                  -0.960562       NaN
# Eating out                                      -0.119725 -0.107689
# Grocery                                          0.138717  0.926525
# Lunch                                           -0.220918 -0.281822
# Out for drinks                                  -0.046010 -0.291111
# Out of town                                      0.280962 -0.625032
# Transportation                                   0.549911  0.050627
#
#                                     Arts&Crafts    Coffee  Eating at Home  \
# Going from home to work                     NaN -0.381452             NaN
# Going from work to home                     NaN -0.403281             NaN
# Hanging out at home                         NaN  0.046769        0.730664
# Left work for a bit, and came back          NaN -0.475884             NaN
# Went out, not to work                       NaN  0.247815       -0.960562
# Working                                     NaN -0.311486             NaN
# Arts&Crafts                            1.000000  0.492101             NaN
# Coffee                                 0.492101  1.000000       -0.121846
# Eating at Home                              NaN -0.121846        1.000000
# Eating out                             0.972192 -0.177194        0.041370
# Grocery                               -0.412446 -0.168611       -0.376880
# Lunch                                 -0.006662  0.162674       -0.195986
# Out for drinks                        -0.350632  0.258416        0.297221
# Out of town                                 NaN -0.033570        0.709378
# Transportation                        -0.645616  0.029752       -0.239358
#
#                                     Eating out   Grocery     Lunch  \
# Going from home to work              -0.429881 -0.121395  0.179227
# Going from work to home               0.775654  0.992059 -0.209777
# Hanging out at home                   0.478270 -0.059380  0.624699
# Left work for a bit, and came back   -0.306007 -0.327740 -0.373126
# Went out, not to work                -0.119725  0.138717 -0.220918
# Working                              -0.107689  0.926525 -0.281822
# Arts&Crafts                           0.972192 -0.412446 -0.006662
# Coffee                               -0.177194 -0.168611  0.162674
# Eating at Home                        0.041370 -0.376880 -0.195986
# Eating out                            1.000000 -0.203671 -0.051402
# Grocery                              -0.203671  1.000000  0.082340
# Lunch                                -0.051402  0.082340  1.000000
# Out for drinks                        0.032462  0.410207  0.107254
# Out of town                           0.313436  0.090803 -0.273039
# Transportation                        0.207196 -0.083578  0.009495
#
#                                     Out for drinks  Out of town  \
# Going from home to work                  -0.411878     0.253556
# Going from work to home                   0.393253    -0.188708
# Hanging out at home                       0.284195    -0.272248
# Left work for a bit, and came back       -0.087757     0.448955
# Went out, not to work                    -0.046010     0.280962
# Working                                  -0.291111    -0.625032
# Arts&Crafts                              -0.350632          NaN
# Coffee                                    0.258416    -0.033570
# Eating at Home                            0.297221     0.709378
# Eating out                                0.032462     0.313436
# Grocery                                   0.410207     0.090803
# Lunch                                     0.107254    -0.273039
# Out for drinks                            1.000000     0.479363
# Out of town                               0.479363     1.000000
# Transportation                           -0.179589    -0.215140
#
#                                     Transportation
# Going from home to work                  -0.476853
# Going from work to home                  -0.347392
# Hanging out at home                      -0.234316
# Left work for a bit, and came back       -0.143721
# Went out, not to work                     0.549911
# Working                                   0.050627
# Arts&Crafts                              -0.645616
# Coffee                                    0.029752
# Eating at Home                           -0.239358
# Eating out                                0.207196
# Grocery                                  -0.083578
# Lunch                                     0.009495
# Out for drinks                           -0.179589
# Out of town                              -0.215140
# Transportation                            1.000000

# %% [markdown]
# That's it. I'll write up another example of how to get findings in another Notebook. Data cleaning is a big part of the work and I wanted to get that portion separately.
